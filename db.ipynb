# %%
import pandas as pd

df = pd.read_excel("final.xlsx")

# %%
df.head()
# Out:
#    seating_no                               arabic_name  total_degree  \
# 0     2001970          احمد محمود السيد عبدالجواد السيد         290.0
# 1     2001971               بلال وحيد طلعت عبدالله عباس         287.0
# 2     2001972               حسام محمد ذكي مبروك عبدالله         179.5
# 3     2001973          عبدالحليم حسين سعد عبدالحليم علي         240.0
# 4     2001974  عبدالرحمن شعبان حسين عبدالجليل عبدالكريم         222.0
#
#   student_case_desc   total %
# 0      ناجح دور أول  90.62500
# 1      ناجح دور أول  89.68750
# 2      ناجح دور أول  56.09375
# 3      ناجح دور أول  75.00000
# 4      ناجح دور أول  69.37500

# %%
df['total %']=df["total_degree"]/320*100

# %%
df["arabic_name"]=df["arabic_name"].str.strip()

# %%
df.to_csv(
    "results.csv",
    index=False,
    encoding="utf-8-sig"
)

print("Done")
# Out:
# Done
